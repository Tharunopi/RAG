# %%
from utils.atlas import mongoClient
from utils.llm_helper import retrieve_thread
import uuid
# Out:
# 2025-10-10 20:37:41.022 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Stack overflow\RAG\.venv\Lib\site-packages\streamlit\runtime\state\session_state.py:469, in SessionState.__getitem__(self, key)
#     468 try:
# --> 469     return self._getitem(widget_id, key)
#     470 except KeyError:
#
# File c:\Stack overflow\RAG\.venv\Lib\site-packages\streamlit\runtime\state\session_state.py:517, in SessionState._getitem(self, widget_id, user_key)
#     516 # We'll never get here
# --> 517 raise KeyError
#
# KeyError:
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 2
# ...

# %%
f = mongoClient()
f.init_db_and_collection()

# %%
type(f.collection.find_one({"email": "df@gmail.com"}))
# Out:
# NoneType
