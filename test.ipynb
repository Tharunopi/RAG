# %%
points=[ScoredPoint(id='c2b21fa1-3c0d-472f-a365-bbf05c410b51', version=0, score=0.36984828, payload={'page_content': "CAREER OBJECTIVEPROJECTS DONE Kangeyam, Tiruppur - 638701 tharunaadhi6@gmail.com+91 9360496526THARUN ATITHYAData Engineer(Fresher)Enthusiastic recent graduate with a passion for problem solving. Seeking an entry-level position to leverage myanalytical abilities and contribute to the success of the organization. Eager to learn from experiencedprofessionals and grow within a challenging and rewarding environment.Web based application AI assitant for farmers Web based recommender for disease usingAyurvedic medicine.Heart disease classification using Machine learning.@TharunopiCompleted 15 days internship on PYTHON inMaxlore Inovations, Calicut. Completed 15 days internship on CV inIsquareCS, Trichy.INTERNSHIP DETAILSACTIVITYWon 2nd prize at a national level conference for'AyurAdvisor' using ML conducted at CIT.Won 2nd prize at a national level conference for'Heart disease classifier' using ANN conducted atSHRI ESWAR.Achieved TOP 10 ranking (out of over 200 teams)at a national level"}, vector=None, shard_key=None, order_value=None), ScoredPoint(id='46247e03-c9a6-4c32-b75b-309d9cd7fbe1', version=0, score=0.32166877, payload={'page_content': "ML conducted at CIT.Won 2nd prize at a national level conference for'Heart disease classifier' using ANN conducted atSHRI ESWAR.Achieved TOP 10 ranking (out of over 200 teams)at a national level conference organized by AnnaUniversity regional campus.WORKSHOPS Participated in a one day workshop on IoTconducted by Saveetha university.Participated in a one day workshop on AutomateIoT  with AI conducted by Velammal engineeringcollege.EDUCATIONBachelor's Degree in Artifical intelligenceand data science(2021 – 2025)Excel engineering collegePythonSQLAzure DataBricksAzure AirFlowSKILLS@Tharun AtithyaCERTIFICATIONSPython for Data science certificate byIBM.Machine learning, Deep learningcertificate by SuperDataScience.TensorFlow advanced certificate byDeeplearning.ai.Data Structures and AlgorithmSpecialization at University ofCalifornia San Diego.PostgreSQL certificate of completionby Pierian Training AREA OF INTERESTNLPANNMachine learningCNNREFERENCEHOD of Artifical Intelligence and Data"}, vector=None, shard_key=None, order_value=None), ScoredPoint(id='99c1ddd8-bcab-4029-9ce1-3f58c49f8b14', version=0, score=0.15010145, payload={'page_content': 'at University ofCalifornia San Diego.PostgreSQL certificate of completionby Pierian Training AREA OF INTERESTNLPANNMachine learningCNNREFERENCEHOD of Artifical Intelligence and Data ScienceProf. P. JayaprabhaPhone - +91 99767 23593Apache SparkPysparkMongoDBAzure DevOps'}, vector=None, shard_key=None, order_value=None)]
# Out:
# NoneType
