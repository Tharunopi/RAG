# %%
import uuid

# %%
id = uuid.uuid4()

# %%
type(id)
# Out:
# uuid.UUID

# %%
df = {
    "name": "tharun"
}

# %%
dd = ()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df.name
#
# AttributeError: 'dict' object has no attribute 'name'
